# %% [markdown]
# <a href="https://colab.research.google.com/github/fowardelcac/credit_card_approval/blob/main/Notebook/Untitled38.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/fowardelcac/credit_card_approval.git
# Out:
# Cloning into 'credit_card_approval'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 39 (delta 3), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (39/39), 7.30 MiB | 2.35 MiB/s, done.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/credit_card_approval/Notebook/Dataset/synthetic_credit_card_approval.csv')
df.head()
# Out:
#    Num_Children  Group  Income  Own_Car  Own_Housing  Target
# 0             4      0   36151        0            0       0
# 1             0      0   36095        1            0       0
# 2             2      1   62110        1            1       0
# 3             0      1   73644        1            0       0
# 4             3      0   99146        0            0       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Num_Children  500000 non-null  int64
#  1   Group         500000 non-null  int64
#  2   Income        500000 non-null  int64
#  3   Own_Car       500000 non-null  int64
#  4   Own_Housing   500000 non-null  int64
#  5   Target        500000 non-null  int64
# dtypes: int64(6)
# memory usage: 22.9 MB

# %% [markdown]
# # Num_children

# %%
df.Num_Children.value_counts().plot(kind='barh')
# Out:
# <Axes: >

# %%
df.Num_Children.describe()
# Out:
# count    500000.000000
# mean          2.000346
# std           1.410574
# min           0.000000
# 25%           1.000000
# 50%           2.000000
# 75%           3.000000
# max          11.000000
# Name: Num_Children, dtype: float64

# %% [markdown]
# - q3: El 75% de los solicitantes tiene 3<=  hijos

# %% [markdown]
# #Group

# %%
df.Group.value_counts().plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# # Income

# %%
sns.histplot(df.Income)
plt.show()

# %%
df.Income.describe()
# Out:
# count    500000.000000
# mean      72507.446898
# std       22960.209440
# min       30000.000000
# 25%       53321.000000
# 50%       72060.000000
# 75%       90670.250000
# max      119999.000000
# Name: Income, dtype: float64

# %% [markdown]
# # Own_Car

# %%
df.Own_Car.value_counts().plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# Un poco mas del doble de los aplicantes posee un auto
#
# #Own_Housing

# %%
df.Own_Housing.value_counts().plot(kind='barh')
# Out:
# <Axes: >

# %%
correlation_matrix = round(df.corr(), 3)

# Configura el tamaño de la figura
plt.figure(figsize=(6, 4))

# Crea el mapa de calor con Seaborn
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')

# Añade los títulos de los ejes
plt.title('Matriz de correlación')
plt.show()
